-- %%
WITH Y1718 AS(
    SELECT YEAR(order_date) [year]
    FROM sales.orders
    WHERE YEAR(order_date) = 2018
)

select 
    ROW_NUMBER() OVER(ORDER BY so.order_id) AS NUM_OF_ORDER,
    so.order_id,
    YEAR(so.order_date) [Order_year],
    so.required_date,
    so.shipped_date,
    soi.item_id,
    soi.quantity,
    soi.list_price,
    soi.discount,
    ss.store_name,
    pp.product_name,
    pb.brand_name,
    pc.category_name,
    sc.*


FROM production.products AS pp
INNER JOIN production.categories AS pc
ON pp.category_id = pc.category_id
INNER JOIN production.brands AS pb
ON pp.brand_id = pb.brand_id
INNER JOIN production.stocks AS ps
ON pp.product_id = ps.product_id
INNER JOIN sales.stores AS ss
ON ps.store_id = ss.store_id
INNER JOIN sales.orders AS so
ON ss.store_id = so.store_id
INNER JOIN sales.customers AS sc
ON so.customer_id = sc.customer_id
INNER JOIN sales.order_items AS soi
ON pp.product_id = soi.product_id AND so.order_id = soi.order_id
INNER JOIN sales.staffs AS sst
ON so.staff_id = sst.staff_id
WHERE ss.store_id = 1 AND YEAR(so.order_date) IN (2017,2018) AND so.shipped_date IS NOT NULL
ORDER BY order_date
-- Out:
-- (449 rows affected)
-- Total execution time: 00:00:00.024
-- <table><tr><th>NUM_OF_ORDER</th><th>order_id</th><th>Order_year</th><th>required_date</th><th>shipped_date</th><th>item_id</th><th>quantity</th><th>list_price</th><th>discount</th><th>store_name</th><th>product_name</th><th>brand_name</th><th>category_name</th><th>customer_id</th><th>first_name</th><th>last_name</th><th>phone</th><th>email</th><th>street</th><th>city</th><th>state</th><th>zip_code</th></tr><tr><td>1</td><td>636</td><td>2017</td><td>2017-01-04</td><td>2017-01-05</td><td>1</td><td>2</td><td>329.99</td><td>0.20</td><td>Santa Cruz Bikes</td><td>Haro Downtown 16 - 2017</td><td>Haro</td><td>Children Bicycles</td><td>532</td><td>Mia</td><td>Delgado</td><td>NULL</td><td>mia.delgado@yahoo.com</td><td>850 Wakehurst Drive </td><td>Coachella</td><td>CA</td><td>92236</td></tr><tr><td>2</td><td>641</td><td>2017</td><td>2017-01-10</td><td>2017-01-08</td><td>1</td><td>1</td><td>529.99</td><td>0.05</td><td>Santa Cruz Bikes</td><td>Electra Moto 1 - 2016</td><td>Electra</td><td>Cruisers Bicycles</td><td>673</td><td>Adam</td><td>Henderson</td><td>NULL</td><td>adam.henderson@hotmail.com</td><td>167 James St. </td><td>Los Banos</td><td>CA</td><td>93635</td></tr><tr><td>3</td><td>641</td><td>2017</td><td>2017-01-10</td><td>2017-01-08</td><td>2</td><td>1</td><td>3499.99</td><td>0.20</td><td>Santa Cruz Bikes</td><td>Trek Boone 7 - 2017</td><td>Trek</td><td>Cyclocross Bicycles</td><td>673</td><td>Adam</td><td>Henderson</td><td>NULL</td><td>adam.henderson@hotmail.com</td><td>167 James St. </td><td>Los